# %%
import pandas as pd

df = pd.read_csv('pokemon_data.csv')
df=pd.DataFrame(df)
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
## Find the Pokemon with "Nan" values and how many are there?
import numpy as np
di=df.index[np.where(pd.isnull(df))[0]]
df.iloc[di]
# Out:
#        #        Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 4      4  Charmander    Fire    NaN   39      52       43       60       50
# 5      5  Charmeleon    Fire    NaN   58      64       58       80       65
# 9      7    Squirtle   Water    NaN   44      48       65       50       64
# 10     8   Wartortle   Water    NaN   59      63       80       65       80
# 11     9   Blastoise   Water    NaN   79      83      100       85      105
# ..   ...         ...     ...    ...  ...     ...      ...      ...      ...
# 775  705     Sliggoo  Dragon    NaN   68      75       53       83      113
# 776  706      Goodra  Dragon    NaN   90     100       70      110      150
# 788  712    Bergmite     Ice    NaN   55      69       85       32       35
# 789  713     Avalugg     Ice    NaN   95     117      184       44       46
# 792  716     Xerneas   Fairy    NaN  126     131       95      131       98
#
#      Speed  Generation  Legendary
# ...

# %%
a=df.loc[df['Legendary']==True]
a
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
leg_df=df.loc[df.loc[:,'Legendary']==True]
print( leg_df)
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 156  144             Articuno       Ice    Flying   90      85      100
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
# ..   ...                  ...       ...       ...  ...     ...      ...
# 795  719              Diancie      Rock     Fairy   50     100      150
# 796  719  DiancieMega Diancie      Rock     Fairy   50     160      110
# 797  720  HoopaHoopa Confined   Psychic     Ghost   80     110       60
# 798  720   HoopaHoopa Unbound   Psychic      Dark   80     160       60
# 799  721            Volcanion      Fire     Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
## Find the mean of the Pokemons with: 
# 'Defense' >50, 
# 'Speed'>75, 
# 'Generation' not more than 3.0
# 'Total' not less than 400
dff=df.loc[(df['Defense']>50) & (df['Speed']>75) & (df['Generation']>3.0)&(df['Defense']+df['Speed']+df['Sp. Atk']+df['Sp. Def']+df['Attack']+df['HP'])]
dff
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense  \
# 436  391             Monferno      Fire  Fighting   64      78       52
# 443  398            Staraptor    Normal    Flying   85     120       70
# 452  407             Roserade     Grass    Poison   60      70       65
# 464  417            Pachirisu  Electric       NaN   60      45       70
# 466  419             Floatzel     Water       NaN   85     105       55
# 477  429            Mismagius     Ghost       NaN   60      60       60
# 483  435             Skuntank    Poison      Dark  103      93       67
# 497  448              Lucario  Fighting     Steel   70     110       70
# 498  448  LucarioMega Lucario  Fighting     Steel   70     145       88
# 519  468             Togekiss     Fairy    Flying   85      50       95
# 520  469              Yanmega       Bug    Flying   86      76       86
# 521  470              Leafeon     Grass       NaN   65     110      130
# ...

# %%
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Legendary, Length: 800, dtype: bool
